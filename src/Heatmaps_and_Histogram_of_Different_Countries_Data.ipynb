# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\Japan_cleaned.csv")

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
data[["Number of Patents Filed"]].hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016C4A891710>]],
#       dtype=object)

# %%
x=data["Year"]
y=data["Number of Patents Published"]
plt.figure(figsize=(10,10))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.show()

xx=data["Year"]
yy=data["Number of Patents Filed"]
plt.figure(figsize=(10,10))
plt.bar(xx,yy,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.show()

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\test.csv")

# %%
data[["Number of Patents Filed"]].hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016C4C5A1320>]],
#       dtype=object)

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\Canada_cleaned.csv")

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
x=data["Year"]
y=data["Number of Patents Published"]
plt.figure(figsize=(10,10))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.show()

xx=data["Year"]
yy=data["Number of Patents Filed"]
plt.figure(figsize=(10,10))
plt.bar(xx,yy,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.show()

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\Germany_cleaned.csv")

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
x=data["Year"]
y=data["Number of Patents Published"]
plt.figure(figsize=(10,10))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.show()

xx=data["Year"]
yy=data["Number of Patents Filed"]
plt.figure(figsize=(10,10))
plt.bar(xx,yy,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.show()

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\United Kingdom_cleaned.csv")

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
x=data["Year"]
y=data["Number of Patents Published"]
plt.figure(figsize=(10,10))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.show()

xx=data["Year"]
yy=data["Number of Patents Filed"]
plt.figure(figsize=(10,10))
plt.bar(xx,yy,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.show()

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\USA.csv")

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
x=data["Year"]
y=data["Number of Patents Published"]
plt.figure(figsize=(10,10))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.show()

xx=data["Year"]
yy=data["Number of Patents Filed"]
plt.figure(figsize=(10,10))
plt.bar(xx,yy,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.show()

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\India.csv")

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
x=data["Year"]
y=data["Number of Patents Published"]
plt.figure(figsize=(10,10))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.show()

xx=data["Year"]
yy=data["Number of Patents Filed"]
plt.figure(figsize=(10,10))
plt.bar(xx,yy,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.show()

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\Australia.csv")

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
x=data["Year"]
y=data["Number of Patents Published"]
plt.figure(figsize=(10,10))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.show()

xx=data["Year"]
yy=data["Number of Patents Filed"]
plt.figure(figsize=(10,10))
plt.bar(xx,yy,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.show()

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\China.csv")

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
x=data["Year"]
y=data["Number of Patents Published"]
plt.figure(figsize=(10,10))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.show()

xx=data["Year"]
yy=data["Number of Patents Filed"]
plt.figure(figsize=(10,10))
plt.bar(xx,yy,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.show()

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\Europe.csv")

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
x=data["Year"]
y=data["Number of Patents Published"]
plt.figure(figsize=(10,10))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.show()

xx=data["Year"]
yy=data["Number of Patents Filed"]
plt.figure(figsize=(10,10))
plt.bar(xx,yy,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.show()

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\CSIR-CDRI\CleanedData_of_Countries\South_Korea.csv")

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
x=data["Year"]
y=data["Number of Patents Published"]
plt.figure(figsize=(10,10))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.show()

xx=data["Year"]
yy=data["Number of Patents Filed"]
plt.figure(figsize=(10,10))
plt.bar(xx,yy,align='center') # A bar chart
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.show()

# %%
data.head()
# Out:
#    Year  Number of Patents Filed  Number of Patents Granted  \
# 0  1999                        0                          0
# 1  2000                        1                          1
# 2  2001                        3                          0
# 3  2002                        6                          0
# 4  2003                       17                          1
#
#    Number of Patents Published  Number of Patents Granted Y Status  \
# 0                            0                                   0
# 1                            0                                   1
# 2                            0                                   0
# 3                            5                                   0
# 4                            6                                   1
#
#    Number of Patents Granted N Status  Number of Patents Granted to Company  \
# 0                                   0                                     0
# ...

# %%
train_df.info()
plt.figure(figsize=(30, 30))
sns.heatmap(train_df.corr(), cmap="coolwarm", annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-2d4c0132fcbd> in <module>
# ----> 1 train_df.info()
#       2 plt.figure(figsize=(30, 30))
#       3 sns.heatmap(train_df.corr(), cmap="coolwarm", annot=True)
#       4 plt.show()
#
# NameError: name 'train_df' is not defined
