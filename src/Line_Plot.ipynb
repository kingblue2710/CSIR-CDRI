# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %%
df_India=pd.read_csv(r'C:\Users\hp\Documents\Projects\CSIR-CDRI\Countries_Cleaned_Data_and_thier_Plotting\CleanedData_of_Countries\India.csv')
df_Japan=pd.read_csv(r'C:\Users\hp\Documents\Projects\CSIR-CDRI\Countries_Cleaned_Data_and_thier_Plotting\CleanedData_of_Countries\Japan_cleaned.csv')
df_USA=pd.read_csv(r'C:\Users\hp\Documents\Projects\CSIR-CDRI\Countries_Cleaned_Data_and_thier_Plotting\CleanedData_of_Countries\USA.csv')
df_Europe=pd.read_csv(r'C:\Users\hp\Documents\Projects\CSIR-CDRI\Countries_Cleaned_Data_and_thier_Plotting\CleanedData_of_Countries\Europe.csv')
df_China=pd.read_csv(r'C:\Users\hp\Documents\Projects\CSIR-CDRI\Countries_Cleaned_Data_and_thier_Plotting\CleanedData_of_Countries\China.csv')
df_Australia=pd.read_csv(r'C:\Users\hp\Documents\Projects\CSIR-CDRI\Countries_Cleaned_Data_and_thier_Plotting\CleanedData_of_Countries\Australia_cleaned.csv')
df_Con_vs_pub=pd.read_csv(r'C:\Users\hp\Desktop\patent_vs_country.csv')

# %%
x_India=df_India["Year"]
y_India=df_India["Number of Patents Published"]
x_Japan=df_Japan["Year"]
y_Japan=df_Japan["Number of Patents Published"]
x_USA=df_USA["Year"]
y_USA=df_USA["Number of Patents Published"]
x_Europe=df_Europe["Year"]
y_Europe=df_Europe["Number of Patents Published"]
x_China=df_China["Year"]
y_China=df_China["Number of Patents Published"]
x_Australia=df_Australia["Year"]
y_Australia=df_Australia["Number of Patents Published"]

# %%
#plt.style.use('ggplot')
plt.figure(figsize=(10,10))
plt.plot(x_India,y_India,label="India")
plt.plot(x_Japan,y_Japan,label="Japan")
plt.plot(x_USA,y_USA,label="USA")
plt.plot(x_Europe,y_Europe,label="Europe")
plt.plot(x_Australia,y_Australia,label="Australia")
plt.xlabel('Year')
plt.ylabel('Number of Patents Published')
plt.legend()
plt.xticks(rotation=90)
plt.savefig('Published vs Year.png')

# %%
x_India=df_India["Year"]
y_India=df_India["Number of Patents Filed"]
x_Japan=df_Japan["Year"]
y_Japan=df_Japan["Number of Patents Filed"]
x_USA=df_USA["Year"]
y_USA=df_USA["Number of Patents Filed"]
x_Europe=df_Europe["Year"]
y_Europe=df_Europe["Number of Patents Filed"]
x_China=df_China["Year"]
y_China=df_China["Number of Patents Filed"]

# %%
plt.style.use('ggplot')
x = np.arange(4)
plt.bar(x+0.0,x_India,y_India,label="India",width=0.2)
plt.bar(x+0.2,x_Japan,y_Japan,label="Japan",width=0.2)
plt.bar(x+0.4,x_USA,y_USA,label="USA",width=0.2)
plt.bar(x+0.6,x_Europe,y_Europe,label="Europe",width=0.2)
plt.bar(x+0.8,x_China,y_China,label="China",width=0.2)
plt.legend()
plt.xlabel('Year')
plt.ylabel('Number of Patents Filed')
plt.xticks(rotation=90)
plt.savefig('Published vs Year.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-e65f660643bb> in <module>
#       1 plt.style.use('ggplot')
#       2 x = np.arange(4)
# ----> 3 plt.bar(x+0.0,x_India,y_India,label="India",width=0.2)
#       4 plt.bar(x+0.2,x_Japan,y_Japan,label="Japan",width=0.2)
#       5 plt.bar(x+0.4,x_USA,y_USA,label="USA",width=0.2)
#
# TypeError: bar() got multiple values for argument 'width'

# %%
x_data=df_Con_vs_pub["Country"]
y_data=df_Con_vs_pub["Number of Patents Published"]

# %%
plt.figure(figsize=(10,10))
plt.bar(x_data,y_data,color=['black', 'red', 'green', 'blue', 'cyan'])
plt.xlabel('Country')
plt.ylabel('Number of Patents Published')
plt.savefig('Published vs country.png')
